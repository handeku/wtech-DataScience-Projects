# %% [markdown]
# # <font color=blue>Assignments for "Visualization with Matplotlib"</font>

# %% [markdown]
# In this assignment, you will make some plots about Corona. First, download the [Coronavirus Source Data](https://ourworldindata.org/coronavirus-source-data).
#
# - First, filter the data for four countries (Spain, France, Germany, Italy) and the last 100 days.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

covid = pd.read_csv("../../data/matplotlib_assignents/owid-covid-data.csv",parse_dates=['date'])
covid.head()
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba 2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba 2020-03-20          4.0        2.0
# 2      ABW  North America    Aruba 2020-03-24         12.0        8.0
# 3      ABW  North America    Aruba 2020-03-25         17.0        5.0
# 4      ABW  North America    Aruba 2020-03-26         19.0        2.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0.0         0.0                   18.733                 18.733
# 1           0.0         0.0                   37.465                 18.733
# 2           0.0         0.0                  112.395                 74.930
# 3           0.0         0.0                  159.227                 46.831
# 4           0.0         0.0                  177.959                 18.733
#
#    ...  aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
covid_Spain=covid[covid.location=='Spain'].sort_values(by=['date'])
covid_Spain_last100=covid_Spain[-100:]
covid_France=covid[covid.location=='France'].sort_values(by=['date'])
covid_France_last100=covid_France[-100:]
covid_Germany=covid[covid.location=='Germany'].sort_values(by=['date'])
covid_Germany_last100=covid_Germany[-100:]
covid_Italy=covid[covid.location=='Italy'].sort_values(by=['date'])
covid_Italy_last100=covid_Italy[-100:]

# %%
covid_4C=pd.concat([covid_Spain_last100,covid_France_last100,covid_Germany_last100,covid_Italy_last100])

# %% [markdown]
# - Create a figure with two subplots. The left subplot will show total cases, and the right one will show total deaths for these countries

# %%
plt.figure(figsize=(25,5))
plt.subplot(1,2,1)
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_cases'],c="orange")
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_cases'],c="green")
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_cases'],c="red")
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_cases'],c="blue")
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"])
plt.subplot(1,2,2)
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_deaths'],c="orange")
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_deaths'],c="green")
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_deaths'],c="red")
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_deaths'],c="blue")
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"]);

# %% [markdown]
# - Set titles, X and Y labels, change the font, font size, and font color for each subplot.

# %%
plt.figure(figsize=(25,7))
plt.subplot(1,2,1)
plt.title('Total Cases by Days',fontsize=16, color="darkgreen", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkgreen")
plt.ylabel('Total Cases',fontsize=14, color="darkgreen")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_cases'],c="orange")
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_cases'],c="green")
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_cases'],c="red")
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_cases'],c="blue")
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"])
plt.subplot(1,2,2)
plt.title('Total Deaths by Days',fontsize=16, color="darkblue", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkblue")
plt.ylabel('Total Deaths',fontsize=14, color="darkblue")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_deaths'],c="orange")
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_deaths'],c="green")
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_deaths'],c="red")
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_deaths'],c="blue")
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"]);

# %% [markdown]
# - Change color, width, and type of lines.

# %%
plt.figure(figsize=(25,7))
plt.subplot(1,2,1)
plt.title('Total Cases by Days',fontsize=16, color="darkgreen", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkgreen")
plt.ylabel('Total Cases',fontsize=14, color="darkgreen")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_cases'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_cases'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_cases'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_cases'],c="blue",linestyle="dashdot",linewidth=6)
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"])
plt.subplot(1,2,2)
plt.title('Total Deaths by Days',fontsize=16, color="darkblue", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkblue")
plt.ylabel('Total Deaths',fontsize=14, color="darkblue")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_deaths'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_deaths'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_deaths'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_deaths'],c="blue",linestyle="dashdot",linewidth=6)
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"]);

# %% [markdown]
# - Put a legend to bottom right.

# %%
plt.figure(figsize=(25,7))
plt.subplot(1,2,1)
plt.title('Total Cases by Days',fontsize=16, color="darkgreen", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkgreen")
plt.ylabel('Total Cases',fontsize=14, color="darkgreen")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_cases'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_cases'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_cases'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_cases'],c="blue",linestyle="dashdot",linewidth=6)
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"],loc=4)
plt.subplot(1,2,2)
plt.title('Total Deaths by Days',fontsize=16, color="darkblue", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkblue")
plt.ylabel('Total Deaths',fontsize=14, color="darkblue")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_deaths'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_deaths'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_deaths'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_deaths'],c="blue",linestyle="dashdot",linewidth=6)
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"],loc=5);

# %% [markdown]
# - Change the color and rotation of the X-axis ticks.

# %%
plt.figure(figsize=(25,7))
plt.subplot(1,2,1)
plt.title('Total Cases by Days',fontsize=16, color="darkgreen", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkgreen")
plt.ylabel('Total Cases',fontsize=14, color="darkgreen")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_cases'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_cases'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_cases'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_cases'],c="blue",linestyle="dashdot",linewidth=6)
plt.xticks(rotation = 30, color="darkblue")
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"],loc=4)
plt.subplot(1,2,2)
plt.title('Total Deaths by Days',fontsize=16, color="darkblue", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkblue")
plt.ylabel('Total Deaths',fontsize=14, color="darkblue")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_deaths'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_deaths'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_deaths'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_deaths'],c="blue",linestyle="dashdot",linewidth=6)
plt.xticks(rotation = 30, color="darkgreen")
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"],loc=5);

# %% [markdown]
# - And set a title for the figure (not for the plots).

# %%
plt.figure(figsize=(25,7))
plt.subplot(1,2,1)
plt.title('Total Cases by Days',fontsize=16, color="darkgreen", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkgreen")
plt.ylabel('Total Cases',fontsize=14, color="darkgreen")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_cases'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_cases'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_cases'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_cases'],c="blue",linestyle="dashdot",linewidth=6)
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"],loc=4)
plt.xticks(rotation = 30, color="darkblue")
plt.subplot(1,2,2)
plt.title('Total Deaths by Days',fontsize=16, color="darkblue", fontname = 'Helvetica')
plt.xlabel("Date(Days)",fontsize=14, color="darkblue")
plt.ylabel('Total Deaths',fontsize=14, color="darkblue")
plt.plot(covid_4C[covid_4C['location']=="Spain"]['date'],covid_4C[covid_4C['location']=="Spain"]['total_deaths'],c="orange", linestyle = "--", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="France"]['date'],covid_4C[covid_4C['location']=="France"]['total_deaths'],c="green", linestyle = ":", linewidth = 4)
plt.plot(covid_4C[covid_4C['location']=="Germany"]['date'],covid_4C[covid_4C['location']=="Germany"]['total_deaths'],c="red", linestyle = "-.", linewidth = 5)
plt.plot(covid_4C[covid_4C['location']=="Italy"]['date'],covid_4C[covid_4C['location']=="Italy"]['total_deaths'],c="blue",linestyle="dashdot",linewidth=6)
plt.legend(["SPAIN","FRANCE","GERMANY","ITALY"],loc=5)
plt.xticks(rotation = 30, color="darkgreen")
plt.suptitle("Total Cases & Deaths by Days for Spain, France, Germany and Italy", fontsize = 20,color = "darkred",fontname='Comic Sans MS');
